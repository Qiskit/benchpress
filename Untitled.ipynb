# %%
from benchpress.utilities.backends import FlexibleBackend

# %%
backend = FlexibleBackend(4, 'heavy-hex')

# %%
set(backend.coupling_map.get_edges())
# Out:
# {(0, 9),
#  (0, 13),
#  (1, 13),
#  (1, 14),
#  (2, 14),
#  (3, 9),
#  (3, 15),
#  (4, 15),
#  (4, 16),
#  (5, 12),
#  (5, 16),
#  (6, 17),
#  (7, 17),
#  (7, 18),
#  (8, 12),
#  (8, 18),
#  (9, 0),
#  (9, 3),
#  (10, 14),
#  (10, 16),
#  (11, 15),
#  (11, 17),
#  (12, 5),
#  (12, 8),
#  (13, 0),
#  (13, 1),
#  (14, 1),
#  (14, 2),
#  (14, 10),
#  (15, 3),
#  (15, 4),
#  (15, 11),
#  (16, 4),
#  (16, 5),
#  (16, 10),
#  (17, 6),
#  (17, 7),
#  (17, 11),
#  (18, 7),
#  (18, 8)}

# %%
backend.coupling_map.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=824x589>
